# %%
#Q.4 Zomato Restaurant
#Zomato Data Analysis is one of the most useful analysis for foodies who want to taste the best
#cuisines of every part of the world which lies in their budget. This analysis is also for those who
#want to find the value for money restaurants in various parts of the country for the cuisines.
#Additionally, this analysis caters the needs of people who are striving to get the best cuisine of
#the country and which locality of that country serves that cuisines with maximum number of
#restaurants.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

import warnings
warnings.filterwarnings('ignore')

# %%
zomato = pd.read_csv('zomato.csv', encoding='latin1')

# %%
zomato
# Out:
#       Restaurant ID           Restaurant Name  Country Code              City  \
# 0           6317637          Le Petit Souffle           162       Makati City
# 1           6304287          Izakaya Kikufuji           162       Makati City
# 2           6300002    Heat - Edsa Shangri-La           162  Mandaluyong City
# 3           6318506                      Ooma           162  Mandaluyong City
# 4           6314302               Sambo Kojin           162  Mandaluyong City
# ...             ...                       ...           ...               ...
# 9546        5915730              NamlÛ± Gurme           208         ÛÁstanbul
# 9547        5908749             Ceviz AÛôacÛ±           208         ÛÁstanbul
# 9548        5915807                     Huqqa           208         ÛÁstanbul
# 9549        5916112              Aôôk Kahve           208         ÛÁstanbul
# 9550        5927402  Walter's Coffee Roastery           208         ÛÁstanbul
#
# ...

# %%
#lets check number of rows and columns:
zomato.shape
# Out:
# (9551, 21)

# %%
zomato.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9551 entries, 0 to 9550
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Restaurant ID         9551 non-null   int64
#  1   Restaurant Name       9551 non-null   object
#  2   Country Code          9551 non-null   int64
#  3   City                  9551 non-null   object
#  4   Address               9551 non-null   object
#  5   Locality              9551 non-null   object
#  6   Locality Verbose      9551 non-null   object
#  7   Longitude             9551 non-null   float64
#  8   Latitude              9551 non-null   float64
#  9   Cuisines              9542 non-null   object
#  10  Average Cost for two  9551 non-null   int64
#  11  Currency              9551 non-null   object
#  12  Has Table booking     9551 non-null   object
#  13  Has Online delivery   9551 non-null   object
#  14  Is delivering now     9551 non-null   object
# ...

# %%
df_country = pd.read_excel('Country-Code.xlsx')

# %%
df_country
# Out:
#     Country Code         Country
# 0              1           India
# 1             14       Australia
# 2             30          Brazil
# 3             37          Canada
# 4             94       Indonesia
# 5            148     New Zealand
# 6            162     Phillipines
# 7            166           Qatar
# 8            184       Singapore
# 9            189    South Africa
# 10           191       Sri Lanka
# 11           208          Turkey
# 12           214             UAE
# 13           215  United Kingdom
# 14           216   United States

# %%
#lets check number of rows and columns:
df_country.shape
# Out:
# (15, 2)

# %%
df_country.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15 entries, 0 to 14
# Data columns (total 2 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Country Code  15 non-null     int64
#  1   Country       15 non-null     object
# dtypes: int64(1), object(1)
# memory usage: 372.0+ bytes

# %%
#Now let's Merge the Zomato and df_country Datasets
zomato_main=pd.merge(zomato,df_country,on='Country Code',how='left')

# %%
zomato_main
# Out:
#       Restaurant ID           Restaurant Name  Country Code              City  \
# 0           6317637          Le Petit Souffle           162       Makati City
# 1           6304287          Izakaya Kikufuji           162       Makati City
# 2           6300002    Heat - Edsa Shangri-La           162  Mandaluyong City
# 3           6318506                      Ooma           162  Mandaluyong City
# 4           6314302               Sambo Kojin           162  Mandaluyong City
# ...             ...                       ...           ...               ...
# 9546        5915730              NamlÛ± Gurme           208         ÛÁstanbul
# 9547        5908749             Ceviz AÛôacÛ±           208         ÛÁstanbul
# 9548        5915807                     Huqqa           208         ÛÁstanbul
# 9549        5916112              Aôôk Kahve           208         ÛÁstanbul
# 9550        5927402  Walter's Coffee Roastery           208         ÛÁstanbul
#
# ...

# %%
## Summary of the dataset now
zomato_main.shape
# Out:
# (9551, 22)

# %%
#after concanating two datasets we have 9551 rows and 22 columns.

# %%
# Summary of the dataset
zomato_main.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9551 entries, 0 to 9550
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Restaurant ID         9551 non-null   int64
#  1   Restaurant Name       9551 non-null   object
#  2   Country Code          9551 non-null   int64
#  3   City                  9551 non-null   object
#  4   Address               9551 non-null   object
#  5   Locality              9551 non-null   object
#  6   Locality Verbose      9551 non-null   object
#  7   Longitude             9551 non-null   float64
#  8   Latitude              9551 non-null   float64
#  9   Cuisines              9542 non-null   object
#  10  Average Cost for two  9551 non-null   int64
#  11  Currency              9551 non-null   object
#  12  Has Table booking     9551 non-null   object
#  13  Has Online delivery   9551 non-null   object
#  14  Is delivering now     9551 non-null   object
# ...

# %%
#there are three different data types: int64,object and float64
#here, we can see are 9 missing values in the column Cuisines.

# %%
#sum of all null values
zomato_main.isnull().sum().sum()
# Out:
# 9

# %%
#let's visualize this using heatmap
sns.heatmap(zomato_main.isnull())
# Out:
# <Axes: >

# %%
zomato_main['Cuisines'].value_counts()
# Out:
# Cuisines
# North Indian                                             936
# North Indian, Chinese                                    511
# Chinese                                                  354
# Fast Food                                                354
# North Indian, Mughlai                                    334
#                                                         ...
# Bengali, Fast Food                                         1
# North Indian, Rajasthani, Asian                            1
# Chinese, Thai, Malaysian, Indonesian                       1
# Bakery, Desserts, North Indian, Bengali, South Indian      1
# Italian, World Cuisine                                     1
# Name: count, Length: 1825, dtype: int64

# %%
zomato_main.drop_duplicates()
zomato_main.shape
# Out:
# (9551, 22)

# %%
#No duplicates values are present.

# %%
zomato_main.isnull().sum()
# Out:
# Restaurant ID           0
# Restaurant Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                9
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# Country                 0
# dtype: int64

# %%
#we have 9 null values out of 9951 rows, it might be reasonable to drop those rows.
zomato_main = zomato_main.dropna(subset=['Cuisines'])

# %%
zomato_main.isnull().sum()
# Out:
# Restaurant ID           0
# Restaurant Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                0
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# Country                 0
# dtype: int64

# %%
#No null values.
#let's revisualize this using heatmap
sns.heatmap(zomato_main.isnull())
# Out:
# <Axes: >

# %%
#Univariate Analysis
sns.kdeplot(x='Country Code', data=zomato_main,fill=True)
plt.show()

# %%
#Whose are having 1 as country code they are having more count.

# %%
sns.kdeplot(data=zomato_main, x='Price range', fill=True)
plt.show()

# %%
#We can see, Price range of 1 has maximum price range followed by 2.
#All Price range are decreasing in order.

# %%
plt.figure(figsize=(9, 4))
sns.histplot(x='Currency',data=zomato_main)
plt.xticks(rotation=90)
plt.show()

# %%
#We can see, Indian Rupees is most used currecny. It means that zomato has main business in India followed by Dollar.

# %%
sns.histplot(x='Has Table booking',data=zomato_main)
plt.show()

# %%
#We can see, maximum places have No table booking. less places with table booking.

# %%
sns.histplot(x='Has Online delivery',data=zomato_main)
plt.show()

# %%
# here,most of places has no online delivery available, compare to online delivery.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(4, 4))  # Adjust the size of the plot as needed
sns.histplot(data=zomato_main['Is delivering now'])  # Assuming 'Online Delivery' is the column with numerical data
plt.show()

# %%
#It depicts, Maximum places are with 'not delivery now' service.

# %%
plt.figure(figsize=(4,4))
sns.kdeplot(x='Aggregate rating',data=zomato_main,fill=True)
plt.show()

# %%
#Most of the coustomer has gives 0 aggregate rating than others.
#After that most of given rating 3.1 and 3.2.

# %%
plt.figure(figsize=(5,4))
sns.histplot(x='Rating color',data=zomato_main)
plt.show()

# %%
#We can see, orange is most used color for rating followed by white.
#Red color shows less people dislike the food delivered by zomato.

# %%
sns.histplot(x='Rating text',data=zomato_main)
plt.show()

# %%
#In rating text, Average is the most used test followed by good.
#many has not given rate too compare to poor,very good and excellent.

# %%
plt.figure(figsize=(6,5))
sns.histplot(y='Country',data=zomato_main)
plt.show()

# %%
#maximum business in India and United states, Rest of all counteries zomato not gives service as in India they gives.

# %%
city_values = zomato_main['City'].value_counts().values
city_labels = zomato_main['City'].value_counts().index
plt.figure(figsize=(5, 6))  
sns.barplot(x=city_labels[:5], y=city_values[:5])
plt.xlabel('City')
plt.ylabel('Count')
plt.title('Top 5 Cities by Count')
plt.xticks(rotation=45)  # Rotate the x-axis labels for better readability
plt.show()

# %%
#zamoto works efficiently in 'New delhi' followed by Gurgoan and Noida, less in faridabad and Ghaziabad.

# %%
top_cuisines = zomato_main['Cuisines'].value_counts().head(5)
print(top_cuisines)
# Out:
# Cuisines
# North Indian             936
# North Indian, Chinese    511
# Chinese                  354
# Fast Food                354
# North Indian, Mughlai    334
# Name: count, dtype: int64

# %%
plt.figure(figsize=(6, 4))
sns.barplot(x=top_cuisines.index, y=top_cuisines.values)
plt.xticks(rotation=45)  
plt.show()

# %%
#We can see, most of people like to eat north Indian cuisine and fast food followed by Chinese.

# %%
top_locations = zomato_main['Locality'].value_counts().head(5)
top_locations
# Out:
# Locality
# Connaught Place    122
# Rajouri Garden      99
# Shahdara            87
# Defence Colony      86
# Pitampura           85
# Name: count, dtype: int64

# %%
plt.figure(figsize=(6, 4))
sns.barplot(x=top_locations.index, y=top_locations.values)
plt.xticks(rotation=45)  # Rotate the x-axis labels for better readability
plt.show()

# %%
#it looks Connaught Place is top among the other places followed by Rajouri Graden.

# %%
sns.kdeplot(zomato_main['Average Cost for two'],fill=True)
plt.show()

# %%
sns.pairplot(zomato_main)
plt.show()

# %%
data_types = zomato_main.dtypes
numerical_vars = data_types[data_types != 'object'].index
categorical_vars = data_types[data_types == 'object'].index

print("Numerical Variables:")
print(numerical_vars)
print("\nCategorical Variables:")
print(categorical_vars)
# Out:
# Numerical Variables:
# Index(['Restaurant ID', 'Country Code', 'Longitude', 'Latitude',
#        'Average Cost for two', 'Price range', 'Aggregate rating', 'Votes'],
#       dtype='object')
#
# Categorical Variables:
# Index(['Restaurant Name', 'City', 'Address', 'Locality', 'Locality Verbose',
#        'Cuisines', 'Currency', 'Has Table booking', 'Has Online delivery',
#        'Is delivering now', 'Switch to order menu', 'Rating color',
#        'Rating text', 'Country'],
#       dtype='object')

# %%
#3.3 Bivariate Analysis
sns.violinplot(x='Has Online delivery',y='Votes',data=zomato_main)
plt.title('Has Online delivery VS Votes')
plt.show()

# %%
#we can observe that median number of votes for both categories vary.

# %%
sns.violinplot(x='Has Online delivery',y='Average Cost for two',data=zomato_main)
plt.title('Has Online delivery VS Average Cost for two')
plt.show()

# %%
#Average cost for two has not affected by online delivery system.

# %%
zomato_main.groupby('Restaurant Name')['Votes'].mean().nlargest(5).plot.bar()
plt.show()

# %%
#Toit is top restaurant compare to other.

# %%
sns.lineplot(x='Average Cost for two',y='Longitude',data=zomato_main)
plt.show()

# %%
#Most of the restaurant are above the 50 Longitute.

# %%
sns.lineplot(x='Rating text',y='Average Cost for two',data=zomato_main)
plt.show()

# %%
#Excellent rate restaurants are having high average cost for two.

# %%
sns.lineplot(x='Average Cost for two',y='Latitude',data=zomato_main)
plt.show()

# %%
#both feature is not have any linear relationship with each others.

# %%
plt.figure(figsize=(6,6))
df_good = zomato_main.sort_values(by="Average Cost for two",ascending=False).iloc[0:5]
sns.lineplot(y="Restaurant Name",x="Average Cost for two",data=df_good)
plt.show()

# %%
#These are the top 5 restaurant name where average cost for two is low than others.Satoo-hotel has high average cost.

# %%
df_good = zomato_main.sort_values(by="Average Cost for two",ascending=False).iloc[0:10]
sns.barplot(y="City",x="Average Cost for two",data=df_good)
plt.show()

# %%
#These are top cities where has high average cost for two in which Jakartha is in to followed bt Tangerang.

# %%
plt.figure(figsize=(4,4))
df_good = zomato_main.sort_values(by="Latitude",ascending=False).iloc[0:5,:]
plt.scatter(df_good["Latitude"], df_good["Restaurant Name"])
plt.xlabel('Latitude')
plt.ylabel('Restaurant Name')
plt.title('Top 5 Restaurants with Highest Latitude')
plt.gca().invert_yaxis()  # Invert y-axis to have the top restaurant at the top
plt.show()

# %%
#We can see, all top 5 restaurant name, where they are generaly lies in nearly same latitude.

# %%
plt.figure(figsize=(4,4))
sns.boxplot(x='Price range',y='Average Cost for two',data=zomato_main)
plt.show()

# %%
#Maximum restaurant are having as price range 3 it means that those are also having high average price range.

# %%
# Find the countrries name that has given 0 rating
zomato_main[zomato_main['Rating color']=='White'].groupby(['Aggregate rating','Country']).size().reset_index()
# Out:
#    Aggregate rating         Country     0
# 0               0.0          Brazil     5
# 1               0.0           India  2139
# 2               0.0  United Kingdom     1
# 3               0.0   United States     3

# %%
#Indian customers are maximum to give 0 rating.
#oppositly, United Kingdom	customers are less.

# %%
sns.histplot(x='Rating color',hue='Price range',data=zomato_main)
plt.show()

# %%
#Here, as per price range the rating color shade has change.

# %%
sns.scatterplot(x='Votes',y='Average Cost for two',data=zomato_main)
plt.show()

# %%
#upto 2000 Votes Average cost has some linear relationship with votes.

# %%
sns.scatterplot(x='Votes',y='Aggregate rating',data=zomato_main)
plt.show()

# %%
#After 2 rating there is little linear relationship.

# %%
#Encoding of DataFrame
zomato_main.drop(columns=['Restaurant ID','Locality Verbose'],axis=1,inplace=True)

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
for col in zomato_main[zomato_main.columns[zomato_main.dtypes == 'object']]:
    zomato_main[col] = le.fit_transform(zomato_main[col])
zomato_main.head()
# Out:
#    Restaurant Name  Country Code  City  Address  Locality   Longitude  \
# 0             3743           162    73     8677       171  121.027535
# 1             3168           162    73     6047       592  121.014101
# 2             2893           162    75     4676       308  121.056831
# 3             4700           162    75     8682       860  121.056475
# 4             5515           162    75     8681       860  121.057508
#
#     Latitude  Cuisines  Average Cost for two  Currency  Has Table booking  \
# 0  14.565443       920                  1100         0                  1
# 1  14.553708      1111                  1200         0                  1
# 2  14.581404      1671                  4000         0                  1
# 3  14.585318      1126                  1500         0                  0
# 4  14.584450      1122                  1500         0                  1
#
#    Has Online delivery  Is delivering now  Switch to order menu  Price range  \
# ...

# %%
zomato_main.describe().T
# Out:
#                        count         mean           std         min  \
# Restaurant Name       9542.0  3648.654265   2140.178731    0.000000
# Country Code          9542.0    18.179208     56.451600    1.000000
# City                  9542.0    77.570530     22.781307    0.000000
# Address               9542.0  4538.486166   2563.438975    0.000000
# Locality              9542.0   657.080277    314.889244    0.000000
# Longitude             9542.0    64.274997     41.197602 -157.948486
# Latitude              9542.0    25.848532     11.010094  -41.330428
# Cuisines              9542.0   989.163173    514.326600    0.000000
# Average Cost for two  9542.0  1200.326137  16128.743876    0.000000
# Currency              9542.0     3.979564      0.912652    0.000000
# Has Table booking     9542.0     0.121358      0.326560    0.000000
# Has Online delivery   9542.0     0.256864      0.436927    0.000000
# Is delivering now     9542.0     0.003563      0.059589    0.000000
# ...

# %%
zomato_main.corr()['Average Cost for two']
# Out:
# Restaurant Name         0.019235
# Country Code            0.043717
# City                   -0.028306
# Address                 0.022680
# Locality               -0.012167
# Longitude               0.045948
# Latitude               -0.111080
# Cuisines                0.005875
# Average Cost for two    1.000000
# Currency                0.045566
# Has Table booking       0.007733
# Has Online delivery    -0.019017
# Is delivering now      -0.001866
# Switch to order menu         NaN
# Price range             0.075111
# Aggregate rating        0.051864
# Rating color           -0.050005
# Rating text             0.031440
# Votes                   0.067833
# Country                -0.003793
# Name: Average Cost for two, dtype: float64

# %%
plt.figure(figsize=(9,6))
sns.heatmap(zomato_main.corr(), annot=True, fmt ='.2f')
plt.show()

# %%
# Distribution of data and skewness
zomato_main.skew()
# Out:
# Restaurant Name          0.044859
# Country Code             3.064922
# City                    -1.191599
# Address                 -0.040534
# Locality                -0.253110
# Longitude               -2.819828
# Latitude                -3.081780
# Cuisines                -0.305923
# Average Cost for two    35.461264
# Currency                 2.879234
# Has Table booking        2.319457
# Has Online delivery      1.113168
# Is delivering now       16.665472
# Switch to order menu     0.000000
# Price range              0.889879
# Aggregate rating        -0.953052
# Rating color             0.046227
# Rating text              0.430970
# Votes                    8.813270
# Country                  3.337828
# dtype: float64

# %%
#Skewness is present.lets handle it.

# %%
plt.figure(figsize=(25, 30))
j = 1
for column in zomato_main.columns:
    if j <= 20:
        plt.subplot(5, 4, j)
        ax = sns.boxplot(x=zomato_main[column])
        plt.xlabel(column, fontsize=20)
    j += 1
plt.tight_layout()
plt.show()

# %%
#Some feature are having outliers but those are categorical features.

# %%
#Lets remove Outliers
from scipy.stats import zscore

z_score = zscore(zomato_main[['Average Cost for two','Votes']]) 
abs_z_score = np.abs(z_score)    
filtering_entry = (abs_z_score  < 3).all(axis=1)

zomato_new = zomato_main[filtering_entry]

# %%
print("old dataset:",zomato_main.shape)
print("new dataset:",zomato_new.shape)
# Out:
# old dataset: (9542, 20)
# new dataset: (9353, 20)

# %%
#lets check Multicollinearity
x = zomato_new.drop(columns=['Average Cost for two'],axis=1)
y = zomato_new['Average Cost for two']

# %%
from sklearn.preprocessing import StandardScaler
scaler= StandardScaler()
scaled_X = scaler.fit_transform(x)
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif = pd.DataFrame()
vif["Features"] = x.columns
vif['vif'] = [variance_inflation_factor(scaled_X,i) for i in range(scaled_X.shape[1])]
vif
# Out:
#                 Features        vif
# 0        Restaurant Name   1.008780
# 1           Country Code  47.755953
# 2                   City   1.080427
# 3                Address   1.104715
# 4               Locality   1.067999
# 5              Longitude   4.966086
# 6               Latitude   3.040538
# 7               Cuisines   1.046344
# 8               Currency   1.291350
# 9      Has Table booking   1.483233
# 10   Has Online delivery   1.168297
# 11     Is delivering now   1.014260
# 12  Switch to order menu        NaN
# 13           Price range   1.951406
# 14      Aggregate rating   1.947086
# 15          Rating color   1.222132
# 16           Rating text   1.426423
# 17                 Votes   1.612761
# 18               Country  65.650108

# %%
#MultiCollinearity exists in Country Code, Switch to order menu and Country Based on ANOVA F scores.

# %%
#Lets Drop columns Country Code, Switch to order menu and Country whose having multicollinearity
zomato_new.drop(columns=['Country Code','Switch to order menu','Country'],axis=1,inplace=True)

# %%
zomato_new.shape
# Out:
# (9353, 17)

# %%
x = zomato_new.drop(columns=['Average Cost for two'],axis=1)
y = zomato_new['Average Cost for two']

# %%
from sklearn.feature_selection import SelectKBest, f_classif
bestfeat = SelectKBest(score_func = f_classif, k = 'all')
fit = bestfeat.fit(x,y)
dfscores = pd.DataFrame(fit.scores_)
dfcolumns = pd.DataFrame(x.columns)

# %%
fit = bestfeat.fit(x,y)
dfscores = pd.DataFrame(fit.scores_)
dfcolumns = pd.DataFrame(x.columns)
dfcolumns.head()
featureScores = pd.concat([dfcolumns,dfscores],axis = 1)
featureScores.columns = ['Feature', 'Score']
print(featureScores.nlargest(35,'Score'))
# Out:
#                 Feature       Score
# 11          Price range  417.271441
# 4             Longitude  140.104252
# 8     Has Table booking   80.537386
# 7              Currency   28.644134
# 15                Votes   25.709621
# 12     Aggregate rating   22.192850
# 5              Latitude   15.795083
# 9   Has Online delivery   11.712468
# 2               Address    7.697943
# 14          Rating text    7.160360
# 1                  City    4.743601
# 13         Rating color    4.082849
# 6              Cuisines    3.874080
# 3              Locality    3.361752
# 10    Is delivering now    2.060959
# 0       Restaurant Name    1.357140

# %%
x_best = x.drop(columns=['Restaurant Name','Is delivering now']).copy()

# %%
#Data Skewness removing
from sklearn.preprocessing import power_transform
x = power_transform(x_best,method='yeo-johnson')
transfer = pd.DataFrame(x)

# %%
transfer.skew()
# Out:
# 0    -0.175578
# 1    -0.302691
# 2    -0.305346
# 3    -0.786756
# 4    -0.259623
# 5    -0.382603
# 6     0.449062
# 7     2.380822
# 8     1.118600
# 9     0.197106
# 10   -0.615638
# 11   -0.100019
# 12   -0.055397
# 13   -0.021212
# dtype: float64

# %%
x = scaler.fit_transform(x)
x
# Out:
# array([[-0.3720683 ,  1.47361131, -1.57029603, ..., -2.27000099,
#         -0.20428665,  1.3031483 ],
#        [-0.3720683 ,  0.61739579, -0.20345804, ..., -2.27000099,
#         -0.20428665,  1.65711165],
#        [-0.27408402,  0.13314147, -1.1168892 , ..., -1.38797154,
#          1.51673089,  1.21983577],
#        ...,
#        [ 3.92597292,  0.58689623, -0.32742453, ...,  1.32428874,
#          0.39781071,  1.72059038],
#        [ 3.92597292,  0.58723958, -0.32742453, ..., -1.38797154,
#          1.51673089,  1.89753872],
#        [ 3.92597292, -0.02455015,  0.03707011, ..., -1.38797154,
#          1.51673089,  1.65711165]])

# %%
#Model Building
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.svm import SVR
from sklearn.neighbors import KNeighborsRegressor
from sklearn.model_selection import RandomizedSearchCV
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score

# %%
#Linear Regression
# finding Best Random state
maxAccu=0
maxRS=0

for i in range(1, 1000):
    X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=i)
    lr=LinearRegression()
    lr.fit(X_train, y_train)
    pred = lr.predict(X_test)
    r2 = r2_score(y_test, pred)
    
    if r2>maxAccu:
        maxAccu=r2
        maxRS=i

print("Best r2 score is", maxAccu,"on Random State", maxRS)
# Out:
# Best r2 score is 0.6019761881414558 on Random State 133

# %%
# Splitting the data into train and test
X_train, X_test, y_train, y_test = train_test_split(x, y, train_size=0.7, test_size=0.3, random_state=16)

# %%
regressors = {
    'Linear Regression' : LinearRegression(),
    
}

results=pd.DataFrame(columns=['MAE','MSE', 'RMSE', 'R2-score'])

for method,func in regressors.items():
    model = func.fit(X_train,y_train)
    pred = model.predict(X_test)
    results.loc[method]= [np.round(mean_absolute_error(y_test,pred),3),
                          np.round(mean_squared_error(y_test,pred),3),
                          np.sqrt(mean_squared_error(y_test,pred)),
                          np.round(r2_score(y_test,pred),3)]
results
# Out:
#                        MAE         MSE        RMSE  R2-score
# Linear Regression  216.717  146830.161  383.184239     0.559

# %%
#Cross - Validation of the model
y_pred = lr.predict(X_test)
from sklearn.model_selection import cross_val_score
lss  = r2_score(y_test,y_pred)

# %%
for j in range(4,10):
    isscore = cross_val_score(lr,x,y,cv=j)
    lsc = isscore.mean()
    print("At cv:-",j)
    print('Cross validation score is:-',lsc*100)
    print('accuracy_score is:-',lss*100)
    print('\n')
# Out:
# At cv:- 4
# Cross validation score is:- 23.961644225554696
# accuracy_score is:- 56.38261016079723
#
#
# At cv:- 5
# Cross validation score is:- 4.092944598861297
# accuracy_score is:- 56.38261016079723
#
#
# At cv:- 6
# Cross validation score is:- 8.40724775910295
# accuracy_score is:- 56.38261016079723
#
#
# At cv:- 7
# Cross validation score is:- 3.103754308142857
# accuracy_score is:- 56.38261016079723
#
#
# At cv:- 8
# Cross validation score is:- 3.4492333619213222
# accuracy_score is:- 56.38261016079723
#
#
# At cv:- 9
# Cross validation score is:- -5.617586301385984
# accuracy_score is:- 56.38261016079723

# %%
lsscore_selected = cross_val_score(lr,x,y,cv=4).mean()
print("The cv score is: ",lsscore_selected,"\nThe accuracy score is: ",lss)
# Out:
# The cv score is:  0.23961644225554696
# The accuracy score is:  0.5638261016079723

# %%
# RandomForest Regressor
# finding Best Random state
maxAccu=0
maxRS=0

for i in range(1, 1000):
    X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=i)
    rf = RandomForestRegressor()
    rf.fit(X_train, y_train)
    pred = rf.predict(X_test)
    r2 = r2_score(y_test, pred)
    
    if r2>maxAccu:
        maxAccu=r2
        maxRS=i

print("Best r2 score is", maxAccu,"on Random State", maxRS)

# %%
# Splitting the data into train and test
X_train, X_test, y_train, y_test = train_test_split(x, y, train_size=0.7, test_size=0.3, random_state=420)

# %%
regressors = {
    
    'Random Forest' : RandomForestRegressor(),
    
}

results=pd.DataFrame(columns=['MAE','MSE', 'RMSE', 'R2-score'])

for method,func in regressors.items():
    model = func.fit(X_train,y_train)
    pred = model.predict(X_test)
    results.loc[method]= [np.round(mean_absolute_error(y_test,pred),3),
                          np.round(mean_squared_error(y_test,pred),3),
                          np.sqrt(mean_squared_error(y_test,pred)),
                          np.round(r2_score(y_test,pred),3)
                          
                         ]
results
# Out:
#                    MAE       MSE       RMSE  R2-score
# Random Forest  105.826  40461.97  201.15161     0.883

# %%
#Cross - Validation of the model
rf = RandomForestRegressor()
rf.fit(X_train,y_train)
y_pred = rf.predict(X_test)
lss  = r2_score(y_test,y_pred)

# %%
for j in range(4,10):
    isscore = cross_val_score(rf,x,y,cv=j)
    lsc = isscore.mean()
    print("At cv:-",j)
    print('Cross validation score is:-',lsc*100)
    print('accuracy_score is:-',lss*100)
    print('\n')
# Out:
# At cv:- 4
# Cross validation score is:- 60.23922585223117
# accuracy_score is:- 88.70564891298535
#
#
# At cv:- 5
# Cross validation score is:- 43.228589942669736
# accuracy_score is:- 88.70564891298535
#
#
# At cv:- 6
# Cross validation score is:- 47.84204722838925
# accuracy_score is:- 88.70564891298535
#
#
# At cv:- 7
# Cross validation score is:- 43.78416985416169
# accuracy_score is:- 88.70564891298535
#
#
# At cv:- 8
# Cross validation score is:- 44.05450791340913
# accuracy_score is:- 88.70564891298535
#
#
# At cv:- 9
# Cross validation score is:- 39.43896523019559
# accuracy_score is:- 88.70564891298535

# %%
lsscore_selected = cross_val_score(rf,x,y,cv=4).mean()
print("The cv score is: ",lsscore_selected,"\nThe accuracy score is: ",lss)
# Out:
# The cv score is:  0.6056241036772607
# The accuracy score is:  0.8839864778939257

# %%
#Gradient Boosting Regressor
#Finding Best Random State
maxAccu=0
maxRS=0

for i in range(1, 1000):
    X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=i)
    gbr = GradientBoostingRegressor()
    gbr.fit(X_train, y_train)
    pred = gbr.predict(X_test)
    r2 = r2_score(y_test, pred)
    
    if r2>maxAccu:
        maxAccu=r2
        maxRS=i

print("Best r2 score is", maxAccu,"on Random State", maxRS)

# %%
# Splitting the data into train and test
X_train, X_test, y_train, y_test = train_test_split(x, y, train_size=0.7, test_size=0.3, random_state=891)

# %%
regressors = {
    
    'Gradient Boost Regressor' : GradientBoostingRegressor(),
    
}

results=pd.DataFrame(columns=['MAE','MSE', 'RMSE', 'R2-score'])

for method,func in regressors.items():
    model = func.fit(X_train,y_train)
    pred = model.predict(X_test)
    results.loc[method]= [np.round(mean_absolute_error(y_test,pred),3),
                          np.round(mean_squared_error(y_test,pred),3),
                          np.sqrt(mean_squared_error(y_test,pred)),
                          np.round(r2_score(y_test,pred),3)
                          
                         ]
results
# Out:
#                               MAE        MSE        RMSE  R2-score
# Gradient Boost Regressor  119.169  47035.632  216.876998     0.873

# %%
#Cross-validation of the model
gbr = GradientBoostingRegressor()
gbr.fit(X_train,y_train)
y_pred = gbr.predict(X_test)
from sklearn.model_selection import cross_val_score
lss  = r2_score(y_test,y_pred)

# %%
for j in range(4,10):
    isscore = cross_val_score(gbr,x,y,cv=j)
    lsc = isscore.mean()
    print("At cv:-",j)
    print('Cross validation score is:-',lsc*100)
    print('accuracy_score is:-',lss*100)
    print('\n')
# Out:
# At cv:- 4
# Cross validation score is:- 68.33478480464835
# accuracy_score is:- 87.33031916538062
#
#
# At cv:- 5
# Cross validation score is:- 58.51471056469387
# accuracy_score is:- 87.33031916538062
#
#
# At cv:- 6
# Cross validation score is:- 56.84080688072193
# accuracy_score is:- 87.33031916538062
#
#
# At cv:- 7
# Cross validation score is:- 54.94693864307171
# accuracy_score is:- 87.33031916538062
#
#
# At cv:- 8
# Cross validation score is:- 54.50774359458295
# accuracy_score is:- 87.33031916538062
#
#
# At cv:- 9
# Cross validation score is:- 52.70429907829492
# accuracy_score is:- 87.33031916538062

# %%
lsscore_selected = cross_val_score(gbr,x,y,cv=4).mean()
print("The cv score is: ",lsscore_selected,"\nThe accuracy score is: ",lss)
# Out:
# The cv score is:  0.682936696225305
# The accuracy score is:  0.8733031916538061

# %%
#KNeighbors Regressor
# finding Best Random state
maxAccu=0
maxRS=0

for i in range(1, 1000):
    X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=i)
    knn = KNeighborsRegressor()
    knn.fit(X_train, y_train)
    pred = knn.predict(X_test)
    r2 = r2_score(y_test, pred)
    
    if r2>maxAccu:
        maxAccu=r2
        maxRS=i

print("Best r2 score is", maxAccu,"on Random State", maxRS)

# %%
# Splitting the data into train and test
X_train, X_test, y_train, y_test = train_test_split(x, y, train_size=0.7, test_size=0.3, random_state=358)

# %%
regressors = {
    
    'KNN Regressor': KNeighborsRegressor()
}

results=pd.DataFrame(columns=['MAE','MSE', 'RMSE', 'R2-score'])

for method,func in regressors.items():
    model = func.fit(X_train,y_train)
    pred = model.predict(X_test)
    results.loc[method]= [np.round(mean_absolute_error(y_test,pred),3),
                          np.round(mean_squared_error(y_test,pred),3),
                          np.sqrt(mean_squared_error(y_test,pred)),
                          np.round(r2_score(y_test,pred),3)
                          
                         ]
results
# Out:
#                    MAE         MSE        RMSE  R2-score
# KNN Regressor  164.958  111368.888  333.719774     0.722

# %%
#Cross-validation of the model
knn = KNeighborsRegressor()
knn.fit(X_train,y_train)
y_pred = knn.predict(X_test)
lss  = r2_score(y_test,y_pred)

# %%
for j in range(4,10):
    isscore = cross_val_score(knn,x,y,cv=j)
    lsc = isscore.mean()
    print("At cv:-",j)
    print('Cross validation score is:-',lsc*100)
    print('accuracy_score is:-',lss*100)
    print('\n')
# Out:
# At cv:- 4
# Cross validation score is:- 43.48955743023085
# accuracy_score is:- 72.1862339968983
#
#
# At cv:- 5
# Cross validation score is:- 32.34193915345439
# accuracy_score is:- 72.1862339968983
#
#
# At cv:- 6
# Cross validation score is:- 37.10114317822413
# accuracy_score is:- 72.1862339968983
#
#
# At cv:- 7
# Cross validation score is:- 35.10729099314186
# accuracy_score is:- 72.1862339968983
#
#
# At cv:- 8
# Cross validation score is:- 31.058986090559802
# accuracy_score is:- 72.1862339968983
#
#
# At cv:- 9
# Cross validation score is:- 27.877336396425246
# accuracy_score is:- 72.1862339968983

# %%
lsscore_selected = cross_val_score(knn,x,y,cv=4).mean()
print("The cv score is: ",lsscore_selected,"\nThe accuracy score is: ",lss)
# Out:
# The cv score is:  0.4348955743023085
# The accuracy score is:  0.721862339968983

# %%
# Selecting The Best Model
#Hyperparameter tuning
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV
# Splitting the data into train and test
X_train, X_test, y_train, y_test = train_test_split(x, y, train_size=0.7, test_size=0.3, random_state=891)

# %%
param = {
             'min_samples_split':[2,5,10],
             'min_samples_leaf':[1,3,4],
             'max_depth':[5,10,15],
             'learning_rate': [0.1,0.2,0.3],
              'n_estimators':[150,200,250],
             }

# %%
grd = GridSearchCV(gbr,param_grid = param)
grd.fit(X_train,y_train)

print('Best Params ',grd.best_params_)

# %%
gbr = GradientBoostingRegressor(learning_rate=0.06, n_estimators=100, min_samples_split=10, min_samples_leaf=3, max_depth=5,)

gbr.fit(X_train,y_train)

pred = gbr.predict(X_test)

r2_score(y_test,pred)
# Out:
# 0.8898194165063099

# %%
######  Plot Actual VS Predicted Averahe Cost for two  #######
plt.figure(figsize=(4,4))
plt.scatter(x=y_test,y=y_pred)
plt.plot(y_test,y_test)
plt.xlabel('Actual Average Cost for two')
plt.ylabel('Predicted Average Cost for two')
plt.show()

# %%
# Saving the Model
import joblib
joblib.dump(gbr,"Cost_For_Two_Prediction.pkl")
# Out:
# ['Cost_For_Two_Prediction.pkl']

# %%
prediction=joblib.load("Cost_For_two_Prediction.pkl")

print(prediction.predict(x))
# Out:
# [1224.19430885 1339.36344077 3022.92604051 ...  297.67839747  309.72139824
#   155.80648186]

# %%
#those are predicted values.

# %%
#######   Model Building For Predicting Price range   #########

# %%
zomato_new.head(5)
# Out:
#    Restaurant Name  City  Address  Locality   Longitude   Latitude  Cuisines  \
# 0             3743    73     8677       171  121.027535  14.565443       920
# 1             3168    73     6047       592  121.014101  14.553708      1111
# 2             2893    75     4676       308  121.056831  14.581404      1671
# 3             4700    75     8682       860  121.056475  14.585318      1126
# 4             5515    75     8681       860  121.057508  14.584450      1122
#
#    Average Cost for two  Currency  Has Table booking  Has Online delivery  \
# 0                  1100         0                  1                    0
# 1                  1200         0                  1                    0
# 2                  4000         0                  1                    0
# 3                  1500         0                  0                    0
# 4                  1500         0                  1                    0
#
# ...

# %%
#lets check Multicollinearity
x = zomato_new.drop(columns=['Price range'],axis=1)
y = zomato_new['Price range']

# %%
from sklearn.preprocessing import StandardScaler
scaler= StandardScaler()
scaled_X = scaler.fit_transform(x)

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif = pd.DataFrame()
vif["Features"] = x.columns
vif['vif'] = [variance_inflation_factor(scaled_X,i) for i in range(scaled_X.shape[1])]
vif
# Out:
#                 Features       vif
# 0        Restaurant Name  1.007200
# 1                   City  1.072790
# 2                Address  1.097730
# 3               Locality  1.067917
# 4              Longitude  1.429252
# 5               Latitude  1.056259
# 6               Cuisines  1.041203
# 7   Average Cost for two  1.739837
# 8               Currency  1.167494
# 9      Has Table booking  1.596652
# 10   Has Online delivery  1.154307
# 11     Is delivering now  1.014089
# 12      Aggregate rating  1.772817
# 13          Rating color  1.207223
# 14           Rating text  1.360184
# 15                 Votes  1.545726

# %%
#MultiCollinearity not exists Based on ANOVA F scores.

# %%
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier

# %%
from sklearn.preprocessing import power_transform
x = power_transform(x,method='yeo-johnson')

# %%
from sklearn.preprocessing import StandardScaler

# transform my dataset into standard normal distribution
sc = StandardScaler()
x = sc.fit_transform(x)
x
# Out:
# array([[ 0.15262913, -0.3720683 ,  1.47361131, ..., -2.27000099,
#         -0.20428665,  1.3031483 ],
#        [-0.1034928 , -0.3720683 ,  0.61739579, ..., -2.27000099,
#         -0.20428665,  1.65711165],
#        [-0.23119606, -0.27408402,  0.13314147, ..., -1.38797154,
#          1.51673089,  1.21983577],
#        ...,
#        [-0.15135377,  3.92597292,  0.58689623, ...,  1.32428874,
#          0.39781071,  1.72059038],
#        [-1.61764731,  3.92597292,  0.58723958, ..., -1.38797154,
#          1.51673089,  1.89753872],
#        [ 1.50183031,  3.92597292, -0.02455015, ..., -1.38797154,
#          1.51673089,  1.65711165]])

# %%
#Balancing the Data
from imblearn.over_sampling import SMOTE as sm

smt_x,smt_y = sm().fit_resample(x,y)

# %%
smt_y.value_counts()
# Out:
# Price range
# 3    4431
# 4    4431
# 2    4431
# 1    4431
# Name: count, dtype: int64

# %%
#LogisticRegression
# finding Best Random state
maxAccu=0
maxRS=0

for i in range(1, 1000):
    x_train, x_test, y_train, y_test = train_test_split(smt_x, smt_y, test_size=0.3, random_state=i)
    lr=LogisticRegression()
    lr.fit(x_train, y_train)
    pred = lr.predict(x_test)
    accuracy = accuracy_score(y_test, pred)
    
    if accuracy>maxAccu:
        maxAccu=accuracy
        maxRS=i

print("Best Accuracy score is", maxAccu,"on Random State", maxRS)
# Out:
# Best Accuracy score is 0.6807070327190673 on Random State 772

# %%
x_train, x_test, y_train, y_test = train_test_split(smt_x, smt_y, test_size=0.3, random_state=641)

# %%
lr = LogisticRegression()
lr.fit(x_train,y_train)

y_pred = lr.predict(x_test)
accuracy_score(y_test,y_pred)
# Out:
# 0.6570139150056412

# %%
#Cross - validation for logistic Regression
from sklearn.model_selection import cross_val_score
pred_lr = lr.predict(x_test)
accu = accuracy_score(y_test,pred_lr)

# %%
for j in range(4,10):
    cross = cross_val_score(lr,x,y,cv=j)
    lsc = cross.mean()
    print("At cv:-",j)
    print('Cross validation score is:-',lsc*100)
    print('accuracy_score is:-',accu*100)
    print('\n')
# Out:
# At cv:- 4
# Cross validation score is:- 78.30686730124921
# accuracy_score is:- 65.70139150056413
#
#
# At cv:- 5
# Cross validation score is:- 76.88539686804219
# accuracy_score is:- 65.70139150056413
#
#
# At cv:- 6
# Cross validation score is:- 75.8904636158208
# accuracy_score is:- 65.70139150056413
#
#
# At cv:- 7
# Cross validation score is:- 75.41040101653728
# accuracy_score is:- 65.70139150056413
#
#
# At cv:- 8
# Cross validation score is:- 75.5818034261148
# accuracy_score is:- 65.70139150056413
#
#
# At cv:- 9
# Cross validation score is:- 75.3789393154167
# accuracy_score is:- 65.70139150056413

# %%
lsscore_selected = cross_val_score(lr,x,y,cv=4).mean()
print("The cv score is: ",lsscore_selected,"\nThe accuracy score is: ",accu)
# Out:
# The cv score is:  0.7830686730124922
# The accuracy score is:  0.6570139150056412

# %%
def metric_score(clf, x_train_ns,x_test,y_train_ns,y_test, train=True):
    if train:
        
        y_pred = clf.predict(x_train_ns)

        print("\nTrain Result")

        print(f"Accuracy Score: {accuracy_score(y_train_ns, y_pred) * 100:.2f}%")

    
    elif train==False:
        pred = clf.predict(x_test)
        
        print("\nTest Result")
        print(f"Accuracy Score: {accuracy_score(y_test,pred) * 100:.2f}%")
        
        print("\n \n Test Classification Report \n", classification_report(y_test, pred, digits=2))
        
        print('\n Confusion Matrix: \n',confusion_matrix(y_test,pred))

# %%
#Random Forest Classifier
# finding Best Random state
maxAccu=0
maxRS=0

for i in range(1, 1000):
    x_train, x_test, y_train, y_test = train_test_split(smt_x, smt_y, test_size=0.3, random_state=i)
    rf=RandomForestClassifier()
    rf.fit(x_train, y_train)
    pred = rf.predict(x_test)
    accuracy = accuracy_score(y_test, pred)
    
    if accuracy>maxAccu:
        maxAccu=accuracy
        maxRS=i

print("Best Accuracy score is", maxAccu,"on Random State", maxRS)

# %%
x_train, x_test, y_train, y_test = train_test_split(smt_x, smt_y, test_size=0.3, random_state=632)
rf = RandomForestClassifier()
rf.fit(x_train,y_train)

metric_score(rf,x_train,x_test,y_train, y_test, train=True)

metric_score(rf,x_train,x_test,y_train, y_test, train=False)
# Out:
# Train Result
# Accuracy Score: 100.00%
#
# Test Result
# Accuracy Score: 98.85%
#
#
#  Test Classification Report
#                precision    recall  f1-score   support
#
#            1       1.00      0.99      0.99      1294
#            2       0.98      0.99      0.99      1343
#            3       0.98      0.98      0.98      1368
#            4       0.99      0.99      0.99      1313
#
#     accuracy                           0.99      5318
#    macro avg       0.99      0.99      0.99      5318
# weighted avg       0.99      0.99      0.99      5318
#
#
#  Confusion Matrix:
#  [[1281   12    1    0]
#  [   3 1326   13    1]
#  [   0   10 1347   11]
#  [   0    0   10 1303]]

# %%
#Cross - Validation for Random Forest classifier
pred_rf = rf.predict(x_test)
accu = accuracy_score(y_test,pred_rf)

# %%
for j in range(4,10):
    cross = cross_val_score(rf,x,y,cv=j)
    lsc = cross.mean()
    print("At cv:-",j)
    print('Cross validation score is:-',lsc*100)
    print('accuracy_score is:-',accu*100)
    print('\n')
# Out:
# At cv:- 4
# Cross validation score is:- 88.09164331813987
# accuracy_score is:- 98.85295223768334
#
#
# At cv:- 5
# Cross validation score is:- 85.59964787625364
# accuracy_score is:- 98.85295223768334
#
#
# At cv:- 6
# Cross validation score is:- 90.82565571612977
# accuracy_score is:- 98.85295223768334
#
#
# At cv:- 7
# Cross validation score is:- 89.92070618886173
# accuracy_score is:- 98.85295223768334
#
#
# At cv:- 8
# Cross validation score is:- 89.5900049717415
# accuracy_score is:- 98.85295223768334
#
#
# At cv:- 9
# Cross validation score is:- 89.60089624310031
# accuracy_score is:- 98.85295223768334

# %%
lsscore_selected = cross_val_score(rf,x,y,cv=6).mean()
print("The cv score is: ",lsscore_selected,"\nThe accuracy score is: ",accu)
# Out:
# The cv score is:  0.9046193469091776
# The accuracy score is:  0.9885295223768334

# %%
#Gradient Boosting Classifier
# finding Best Random state
maxAccu=0
maxRS=0

for i in range(1, 1000):
    x_train, x_test, y_train, y_test = train_test_split(smt_x, smt_y, test_size=0.3, random_state=i)
    gbc=GradientBoostingClassifier()
    gbc.fit(x_train, y_train)
    pred = gbc.predict(x_test)
    accuracy = accuracy_score(y_test, pred)
    
    if accuracy>maxAccu:
        maxAccu=accuracy
        maxRS=i

print("Best Accuracy score is", maxAccu,"on Random State", maxRS)

# %%
x_train, x_test, y_train, y_test = train_test_split(smt_x, smt_y, test_size=0.3, random_state=592)

# %%
gbc=GradientBoostingClassifier()
gbc.fit(x_train,y_train)

metric_score(gbc,x_train,x_test,y_train, y_test, train=True)

metric_score(gbc,x_train,x_test,y_train, y_test, train=False)
# Out:
# Train Result
# Accuracy Score: 98.65%
#
# Test Result
# Accuracy Score: 97.63%
#
#
#  Test Classification Report
#                precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00      1336
#            2       0.97      0.98      0.98      1379
#            3       0.95      0.96      0.96      1280
#            4       0.98      0.97      0.97      1323
#
#     accuracy                           0.98      5318
#    macro avg       0.98      0.98      0.98      5318
# weighted avg       0.98      0.98      0.98      5318
#
#
#  Confusion Matrix:
#  [[1332    4    0    0]
#  [   5 1358   14    2]
#  [   0   35 1223   22]
#  [   0    0   44 1279]]

# %%
#Cross - validation For GradientBoosting Classifier
pred_gbc = gbc.predict(x_test)
accu = accuracy_score(y_test,pred_gbc)

# %%
for j in range(4,10):
    cross = cross_val_score(gbc,x,y,cv=j)
    lsc = cross.mean()
    print("At cv:-",j)
    print('Cross validation score is:-',lsc*100)
    print('accuracy_score is:-',accu*100)
    print('\n')
# Out:
# At cv:- 4
# Cross validation score is:- 85.68672372472425
# accuracy_score is:- 97.63068822865739
#
#
# At cv:- 5
# Cross validation score is:- 83.11951914529963
# accuracy_score is:- 97.63068822865739
#
#
# At cv:- 6
# Cross validation score is:- 89.64948236295773
# accuracy_score is:- 97.63068822865739
#
#
# At cv:- 7
# Cross validation score is:- 89.1513212489435
# accuracy_score is:- 97.63068822865739
#
#
# At cv:- 8
# Cross validation score is:- 89.51534659618491
# accuracy_score is:- 97.63068822865739
#
#
# At cv:- 9
# Cross validation score is:- 89.82574878869394
# accuracy_score is:- 97.63068822865739

# %%
lsscore_selected = cross_val_score(gbc,x,y,cv=9).mean()
print("The cv score is: ",lsscore_selected,"\nThe accuracy score is: ",accu)
# Out:
# The cv score is:  0.8968685989980505
# The accuracy score is:  0.9763068822865739

# %%
#SVC
#Finding Best Random State
from sklearn.svm import SVC
maxAccu=0
maxRS=0

for i in range(1, 1000):
    x_train, x_test, y_train, y_test = train_test_split(smt_x, smt_y, test_size=0.3, random_state=i)
    svc=SVC()
    svc.fit(x_train, y_train)
    pred = svc.predict(x_test)
    accuracy = accuracy_score(y_test, pred)
    
    if accuracy>maxAccu:
        maxAccu=accuracy
        maxRS=i

print("Best Accuracy score is", maxAccu,"on Random State", maxRS)

# %%
x_train, x_test, y_train, y_test = train_test_split(smt_x, smt_y, test_size=0.3, random_state=521)

# %%
svc = SVC()
svc.fit(x_train,y_train)

metric_score(svc,x_train,x_test,y_train, y_test, train=True)

metric_score(svc,x_train,x_test,y_train, y_test, train=False)
# Out:
# Train Result
# Accuracy Score: 94.70%
#
# Test Result
# Accuracy Score: 93.46%
#
#
#  Test Classification Report
#                precision    recall  f1-score   support
#
#            1       0.98      0.95      0.96      1283
#            2       0.93      0.90      0.92      1392
#            3       0.89      0.93      0.91      1331
#            4       0.95      0.96      0.96      1312
#
#     accuracy                           0.93      5318
#    macro avg       0.94      0.94      0.94      5318
# weighted avg       0.94      0.93      0.93      5318
#
#
#  Confusion Matrix:
#  [[1216   60    6    1]
#  [  28 1258  101    5]
#  [   0   37 1232   62]
#  [   0    2   46 1264]]

# %%
#Cross - Validation for SVC
pred_svc = svc.predict(x_test)
accu = accuracy_score(y_test,pred_svc)

# %%
for j in range(4,10):
    cross = cross_val_score(svc,x,y,cv=j)
    lsc = cross.mean()
    print("At cv:-",j)
    print('Cross validation score is:-',lsc*100)
    print('accuracy_score is:-',accu*100)
    print('\n')
# Out:
# At cv:- 4
# Cross validation score is:- 84.38085503700958
# accuracy_score is:- 93.45618653629184
#
#
# At cv:- 5
# Cross validation score is:- 85.00029438917105
# accuracy_score is:- 93.45618653629184
#
#
# At cv:- 6
# Cross validation score is:- 84.8814137849356
# accuracy_score is:- 93.45618653629184
#
#
# At cv:- 7
# Cross validation score is:- 84.18995164921785
# accuracy_score is:- 93.45618653629184
#
#
# At cv:- 8
# Cross validation score is:- 83.88045337895637
# accuracy_score is:- 93.45618653629184
#
#
# At cv:- 9
# Cross validation score is:- 83.82772718672622
# accuracy_score is:- 93.45618653629184

# %%
lsscore_selected = cross_val_score(svc,x,y,cv=5).mean()
print("The cv score is: ",lsscore_selected,"\nThe accuracy score is: ",accu)

# %%
#KNN
#Finding Random State
from sklearn.neighbors import KNeighborsClassifier
# finding Best Random state
maxAccu=0
maxRS=0

for i in range(1, 1000):
    x_train, x_test, y_train, y_test = train_test_split(smt_x, smt_y, test_size=0.3, random_state=i)
    knn=KNeighborsClassifier()
    knn.fit(x_train, y_train)
    pred = knn.predict(x_test)
    accuracy = accuracy_score(y_test, pred)
    
    if accuracy>maxAccu:
        maxAccu=accuracy
        maxRS=i

print("Best Accuracy score is", maxAccu,"on Random State", maxRS)

# %%
x_train, x_test, y_train, y_test = train_test_split(smt_x, smt_y, test_size=0.3, random_state=950)

# %%
knn = KNeighborsClassifier()
knn.fit(x_train,y_train)

metric_score(knn,x_train,x_test,y_train, y_test, train=True)

metric_score(knn,x_train,x_test,y_train, y_test, train=False)

# %%
#Cross - Validation for KNN
pred_knn = knn.predict(x_test)
accu = accuracy_score(y_test,pred_knn)

# %%
for j in range(4,10):
    cross = cross_val_score(knn,x,y,cv=j)
    lsc = cross.mean()
    print("At cv:-",j)
    print('Cross validation score is:-',lsc*100)
    print('accuracy_score is:-',accu*100)
    print('\n')

# %%
lsscore_selected = cross_val_score(knn,x,y,cv=8).mean()
print("The cv score is: ",lsscore_selected,"\nThe accuracy score is: ",accu)

# %%
#Selecting Best Model
#Hyperparameter Tuning
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV
x_train, x_test, y_train, y_test = train_test_split(smt_x, smt_y, test_size=0.3, random_state=592)
param = {
    'max_depth': range(4,8),
    'min_samples_split': range(2,8,2),
    'learning_rate': np.arange(0.1,0.3),
    'n_estimators':[150,200,250],
    'min_samples_leaf':[2,3,4,5]
}

# %%
gbc=GradientBoostingClassifier()

# %%
rt = RandomizedSearchCV(gbc,param_distributions = param)

rt.fit(x_train,y_train)
rt.best_params_

# %%
gbc=GradientBoostingClassifier(max_depth=7 , min_samples_split=4, min_samples_leaf=5, learning_rate=0.1, n_estimators=200)
gbc.fit(x_train,y_train)

metric_score(gbc,x_train,x_test,y_train, y_test, train=True)

metric_score(gbc,x_train,x_test,y_train, y_test, train=False)
# Out:
# Train Result
# Accuracy Score: 100.00%
#
# Test Result
# Accuracy Score: 99.02%
#
#
#  Test Classification Report
#                precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00      1336
#            2       0.99      0.99      0.99      1379
#            3       0.98      0.99      0.98      1280
#            4       0.99      0.99      0.99      1323
#
#     accuracy                           0.99      5318
#    macro avg       0.99      0.99      0.99      5318
# weighted avg       0.99      0.99      0.99      5318
#
#
#  Confusion Matrix:
#  [[1332    4    0    0]
#  [   1 1368    9    1]
#  [   0    9 1262    9]
#  [   0    0   19 1304]]

# %%
#ROC_AUC Curve
from sklearn.metrics import roc_curve, auc
#predicting the data
y_pred_cnb = gbc.predict(x_test)
y_prob_pred_cnb = gbc.predict_proba(x_test)

# %%
# roc curve for classes
fpr = {}
tpr = {}
thresh ={}

n_class = 4

for i in range(n_class):    
    fpr[i], tpr[i], thresh[i] = roc_curve(y_test, y_prob_pred_cnb[:,i], pos_label=i)
    
# plotting    
plt.plot(fpr[0], tpr[0], linestyle='--', label='Class 1 vs Rest')
plt.plot(fpr[1], tpr[1], linestyle='--', label='Class 2 vs Rest')
plt.plot(fpr[2], tpr[2], linestyle='--', label='Class 3 vs Rest')
plt.plot(fpr[3], tpr[3], linestyle='--', label='Class 4 vs Rest')


plt.title('Multiclass ROC curve')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive rate')
plt.legend(loc='best')

# %%
#  saving Model 
import joblib
joblib.dump(gbc,"Price_Range_Prediction.pkl")
# Out:
# ['Price_Range_Prediction.pkl']

# %%
mod=joblib.load("Price_range_prediction.pkl")
print(mod.predict(x))
# Out:
# [3 3 4 ... 4 4 2]

# %%
Prediction_range = pd.DataFrame({'Predictions': mod.predict(x), 'Actual Values': y})
Prediction_range.head(10)
# Out:
#    Predictions  Actual Values
# 0            3              3
# 1            3              3
# 2            4              4
# 3            4              4
# 4            4              4
# 5            3              3
# 6            4              4
# 7            4              4
# 8            4              4
# 9            3              3
